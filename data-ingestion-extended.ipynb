# %% [markdown]
# ## Initial Setup

# %%
# Install required PDF processing libraries
# !pip install reportlab
# !pip install fpdf
# !pip install pdfplumber
# Out:
# Requirement already satisfied: reportlab in /usr/local/lib/python3.11/dist-packages (4.4.5)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from reportlab) (11.3.0)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from reportlab) (3.4.4)
# Requirement already satisfied: fpdf in /usr/local/lib/python3.11/dist-packages (1.7.2)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.11/dist-packages (0.11.8)
# Requirement already satisfied: pdfminer.six==20251107 in /usr/local/lib/python3.11/dist-packages (from pdfplumber) (20251107)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from pdfplumber) (5.1.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20251107->pdfplumber) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20251107->pdfplumber) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (2.23)

# %%
# Standard library imports
import os
import re
import datetime as dt
import shutil
from urllib.parse import urljoin

# Third-party libraries
import requests
import pdfplumber
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from reportlab.pdfgen import canvas
from fpdf import FPDF
from typing import Optional, Dict, Any, Tuple

# %%
# Base configuration for dataset extraction
BASE_URL = "https://ncdc.gov.ng"
HTML_FILE = "/kaggle/input/ncdc-table/ncdc_table.html"
SAVE_DIR = "/kaggle/working/ncdc_reports"

# Starting point for serial number and week tracking
START_SN = 305      # Serial number for Week 1, 2020
START_YEAR = 2020
START_WEEK = 1

# Make and ensure output directory exists
os.makedirs(SAVE_DIR, exist_ok=True)

# %% [markdown]
# ## URL extraction from HTML file

# %%
# Load saved HTML table from local file
with open(HTML_FILE, "r", encoding="utf-8") as f:
    soup = BeautifulSoup(f, "html.parser")  # parse HTML with BeautifulSoup

# Get all table rows, skipping header
rows = soup.find_all("tr")[1:]  # skip header row

# Initialize list to store serial number (SN) and PDF link info
pdf_data = []

# Extract SN, title, and PDF URL from each row
for row in rows:
    cols = row.find_all("td")
    if len(cols) >= 3:
        sn = cols[0].get_text(strip=True)  # extract serial number
        title = cols[1].get_text(strip=True)  # extract report title
        link_tag = cols[2].find("a", href=True)  # find anchor tag in third column
        if link_tag:
            pdf_url = urljoin(BASE_URL, link_tag['href'])  # construct full PDF URL
            pdf_data.append((int(sn), title, pdf_url))

# Sort the PDF data by serial number ascending
pdf_data.sort(key=lambda x: x[0])

# Output total number of PDFs found
print(f"Total PDFs found: {len(pdf_data)}")

# Preview first 9 entries
for sn, title, url in pdf_data[:9]:
    print(f"SN {sn} | Title: {title} | URL: {url}")
# Out:
# Total PDFs found: 441
# SN 1 | Title: An update of Lassa fever outbreak in Nigeria for Week 45 | URL: https://ncdc.gov.ng/themes/common/files/sitreps/471dd6384cd4f288167c0881efee40ee.pdf
# SN 2 | Title: An update of Lassa fever outbreak in Nigeria for Week 44 | URL: https://ncdc.gov.ng/themes/common/files/sitreps/9910b5860f5b9c377cf14a8992d6905b.pdf
# SN 3 | Title: An update of Lassa fever outbreak in Nigeria for Week 43 | URL: https://ncdc.gov.ng/themes/common/files/sitreps/55b33161bbfe39fd72039808875e5c45.pdf
# SN 4 | Title: An update of Lassa fever outbreak in Nigeria for Week 42 | URL: https://ncdc.gov.ng/themes/common/files/sitreps/91f559d691c7cd411f7058f1496eef6f.pdf
# SN 5 | Title: An update of Lassa fever outbreak in Nigeria for Week 41 | URL: https://ncdc.gov.ng/themes/common/files/sitreps/68f0ee9000f3084b74ed892be0d3f79f.pdf
# SN 6 | Title: An update of Lassa fever outbreak in Nigeria for Week 40 | URL: https://ncdc.gov.ng/themes/common/files/sitreps/ded728ef465f33739ad7928d327a2929.pdf
# SN 7 | Title: An update of Lassa fever outbreak in Nigeria for Week 39 | URL: https://ncdc.gov.ng/themes/common/files/sitreps/29888ec0c2dd10ca4cf0bef3814d0a81.pdf
# SN 8 | Title: An update of Lassa fever outbreak in Nigeria for Week 38 | URL: https://ncdc.gov.ng/themes/common/files/sitreps/bc2702d096dea7bcb5f8cb520aefba7c.pdf
# SN 9 | Title: An update of Lassa fever outbreak in Nigeria for Week 37 | URL: https://ncdc.gov.ng/themes/common/files/sitreps/8ce0c6f500bad860e93baa694da23a62.pdf

# %% [markdown]
# ## PDF file download

# %%
# Helper functions for downloading PDFs

def has_53_weeks(year: int) -> bool:
    """
    Check if a given year has 53 ISO weeks.
    
    Args:
        year (int): Year to check.
        
    Returns:
        bool: True if year has 53 weeks, else False.
    """
    # ISO calendar: week number of Dec 31 determines if year has 53 weeks
    return dt.date(year, 12, 31).isocalendar()[1] == 53


def download_pdf(url: str, filename: str) -> bool:
    """
    Download a PDF from a URL and save it locally.
    
    Args:
        url (str): URL of the PDF.
        filename (str): Name to save the PDF as.
        
    Returns:
        bool: True if download succeeds, False otherwise.
    """
    try:
        response = requests.get(url, timeout=30)  # fetch PDF
        response.raise_for_status()  # raise error for bad status
        with open(os.path.join(SAVE_DIR, filename), 'wb') as f:
            f.write(response.content)  # save file
        print(f"✓ Downloaded: {filename}")
        return True
    except Exception as e:
        print(f"✗ Failed to download {filename}: {e}")
        return False

# %%
"""
Process PDFs for all serial numbers (SN) from START_SN downward.
Downloads existing PDFs or creates placeholders if missing.
Calculates the correct year and ISO week, accounting for 52/53-week years.
"""

# Determine the actual minimum and maximum SN in the data
min_sn = min(sn for sn, _, _ in pdf_data)
max_sn = max(sn for sn, _, _ in pdf_data)

print(f"SN range in data: {min_sn} to {max_sn}")
print(f"\nProcessing SN range: {START_SN} to {min_sn}")

# Loop over SNs from START_SN downward
for sn in range(START_SN, min_sn - 1, -1): # uncomment when not testing
# for sn in range(START_SN, START_SN - 10, -1): # for testing
    # Calculate week offset from START_SN
    week_offset = START_SN - sn  # 0 for SN 305, 1 for SN 304, etc.
    year = START_YEAR
    week = START_WEEK + week_offset
    
    # Adjust year and week if week exceeds total weeks in current year
    weeks_in_year = 53 if has_53_weeks(year) else 52
    while week > weeks_in_year:
        year += 1
        week -= weeks_in_year
    
    # Construct filename for the PDF
    filename = f"{year}-W{week:02d}.pdf"
    
    # Find PDF info for this SN
    pdf_info = next((item for item in pdf_data if item[0] == sn), None)
    
    if pdf_info:
        # Download the PDF if it exists
        _, title, url = pdf_info
        print(f"SN {sn}: Downloading {filename} - {title}")
        download_pdf(url, filename)
    else:
        # Create a placeholder PDF if missing
        print(f"SN {sn}: Creating placeholder for {filename} (missing)")
        create_placeholder_pdf(filename, f"{year} Week {week}")

print(f"\nProcessing complete!")
print(f"Files saved to: {SAVE_DIR}")
# Out:
# SN range in data: 1 to 441
#
# Processing SN range: 305 to 1
# SN 305: Downloading 2020-W01.pdf - An update of Lassa fever outbreak in Nigeria for Week 1
# ✓ Downloaded: 2020-W01.pdf
# SN 304: Downloading 2020-W02.pdf - An update of Lassa fever outbreak in Nigeria for Week 2
# ✓ Downloaded: 2020-W02.pdf
# SN 303: Downloading 2020-W03.pdf - An update of Lassa fever outbreak in Nigeria for Week 3
# ✓ Downloaded: 2020-W03.pdf
# SN 302: Downloading 2020-W04.pdf - An update of Lassa fever outbreak in Nigeria for Week 4
# ✓ Downloaded: 2020-W04.pdf
# SN 301: Downloading 2020-W05.pdf - An update of Lassa fever outbreak in Nigeria for Week 5
# ✓ Downloaded: 2020-W05.pdf
# SN 300: Downloading 2020-W06.pdf - An update of Lassa fever outbreak in Nigeria for Week 6
# ✓ Downloaded: 2020-W06.pdf
# SN 299: Downloading 2020-W07.pdf - An update of Lassa fever outbreak in Nigeria for Week 7
# ✓ Downloaded: 2020-W07.pdf
# SN 298: Downloading 2020-W08.pdf - An update of Lassa fever outbreak in Nigeria for Week 8
# ✓ Downloaded: 2020-W08.pdf
# SN 297: Downloading 2020-W09.pdf - An update of Lassa fever outbreak in Nigeria for Week 9
# ✓ Downloaded: 2020-W09.pdf
# SN 296: Downloading 2020-W10.pdf - An update of Lassa fever outbreak in Nigeria for Week 10
# ✓ Downloaded: 2020-W10.pdf
# SN 295: Downloading 2020-W11.pdf - An update of Lassa fever outbreak in Nigeria for Week 11
# ✓ Downloaded: 2020-W11.pdf
# SN 294: Downloading 2020-W12.pdf - An update of Lassa fever outbreak in Nigeria for Week 12
# ✓ Downloaded: 2020-W12.pdf
# SN 293: Downloading 2020-W13.pdf - An update of Lassa fever outbreak in Nigeria for Week 13
# ✓ Downloaded: 2020-W13.pdf
# SN 292: Downloading 2020-W14.pdf - An update of Lassa fever outbreak in Nigeria for Week 14
# ✓ Downloaded: 2020-W14.pdf
# SN 291: Downloading 2020-W15.pdf - An update of Lassa fever outbreak in Nigeria for Week 15
# ✓ Downloaded: 2020-W15.pdf
# SN 290: Downloading 2020-W16.pdf - An update of Lassa fever outbreak in Nigeria for Week 16
# ✓ Downloaded: 2020-W16.pdf
# SN 289: Downloading 2020-W17.pdf - An update of Lassa fever outbreak in Nigeria for Week 17
# ✓ Downloaded: 2020-W17.pdf
# SN 288: Downloading 2020-W18.pdf - An update of Lassa fever outbreak in Nigeria for Week 18
# ✓ Downloaded: 2020-W18.pdf
# SN 287: Downloading 2020-W19.pdf - An update of Lassa fever outbreak in Nigeria for Week 19
# ✓ Downloaded: 2020-W19.pdf
# SN 286: Downloading 2020-W20.pdf - An update of Lassa fever outbreak in Nigeria for Week 20
# ✓ Downloaded: 2020-W20.pdf
# SN 285: Downloading 2020-W21.pdf - An update of Lassa fever outbreak in Nigeria for Week 21
# ✓ Downloaded: 2020-W21.pdf
# SN 284: Downloading 2020-W22.pdf - An update of Lassa fever outbreak in Nigeria for Week 22
# ✓ Downloaded: 2020-W22.pdf
# SN 283: Downloading 2020-W23.pdf - An update of Lassa fever outbreak in Nigeria for Week 23
# ✓ Downloaded: 2020-W23.pdf
# SN 282: Downloading 2020-W24.pdf - An update of Lassa fever outbreak in Nigeria for Week 24
# ✓ Downloaded: 2020-W24.pdf
# SN 281: Downloading 2020-W25.pdf - An update of Lassa fever outbreak in Nigeria for Week 25
# ✓ Downloaded: 2020-W25.pdf
# SN 280: Downloading 2020-W26.pdf - An update of Lassa fever outbreak in Nigeria for Week 26
# ✓ Downloaded: 2020-W26.pdf
# SN 279: Downloading 2020-W27.pdf - An update of Lassa fever outbreak in Nigeria for Week 27
# ✓ Downloaded: 2020-W27.pdf
# SN 278: Downloading 2020-W28.pdf - An update of Lassa fever outbreak in Nigeria for Week 28
# ✓ Downloaded: 2020-W28.pdf
# SN 277: Downloading 2020-W29.pdf - An update of Lassa fever outbreak in Nigeria for Week 29
# ✓ Downloaded: 2020-W29.pdf
# SN 276: Downloading 2020-W30.pdf - An update of Lassa fever outbreak in Nigeria for Week 30
# ✓ Downloaded: 2020-W30.pdf
# SN 275: Downloading 2020-W31.pdf - An update of Lassa fever outbreak in Nigeria for Week 31
# ✓ Downloaded: 2020-W31.pdf
# SN 274: Downloading 2020-W32.pdf - An update of Lassa fever outbreak in Nigeria for Week 32
# ✓ Downloaded: 2020-W32.pdf
# SN 273: Downloading 2020-W33.pdf - An update of Lassa fever outbreak in Nigeria for Week 33
# ✓ Downloaded: 2020-W33.pdf
# SN 272: Downloading 2020-W34.pdf - An update of Lassa fever outbreak in Nigeria for Week 34
# ✓ Downloaded: 2020-W34.pdf
# SN 271: Downloading 2020-W35.pdf - An update of Lassa fever outbreak in Nigeria for Week 35
# ✓ Downloaded: 2020-W35.pdf
# SN 270: Downloading 2020-W36.pdf - An update of Lassa fever outbreak in Nigeria for Week 36
# ✓ Downloaded: 2020-W36.pdf
# SN 269: Downloading 2020-W37.pdf - An update of Lassa fever outbreak in Nigeria for Week 37
# ✓ Downloaded: 2020-W37.pdf
# SN 268: Downloading 2020-W38.pdf - An update of Lassa fever outbreak in Nigeria for Week 38
# ✓ Downloaded: 2020-W38.pdf
# SN 267: Downloading 2020-W39.pdf - An update of Lassa fever outbreak in Nigeria for Week 39
# ✓ Downloaded: 2020-W39.pdf
# SN 266: Downloading 2020-W40.pdf - An update of Lassa fever outbreak in Nigeria for Week 40
# ✓ Downloaded: 2020-W40.pdf
# SN 265: Downloading 2020-W41.pdf - An update of Lassa fever outbreak in Nigeria for Week 41
# ✓ Downloaded: 2020-W41.pdf
# SN 264: Downloading 2020-W42.pdf - An update of Lassa fever outbreak in Nigeria for Week 42
# ✓ Downloaded: 2020-W42.pdf
# SN 263: Downloading 2020-W43.pdf - An update of Lassa fever outbreak in Nigeria for Week 43
# ✓ Downloaded: 2020-W43.pdf
# SN 262: Downloading 2020-W44.pdf - An update of Lassa fever outbreak in Nigeria for Week 44
# ✓ Downloaded: 2020-W44.pdf
# SN 261: Downloading 2020-W45.pdf - An update of Lassa fever outbreak in Nigeria for Week 45
# ✓ Downloaded: 2020-W45.pdf
# SN 260: Downloading 2020-W46.pdf - An update of Lassa fever outbreak in Nigeria for Week 46
# ✓ Downloaded: 2020-W46.pdf
# SN 259: Downloading 2020-W47.pdf - An update of Lassa fever outbreak in Nigeria for Week 47
# ✓ Downloaded: 2020-W47.pdf
# SN 258: Downloading 2020-W48.pdf - An update of Lassa fever outbreak in Nigeria for Week 48
# ✓ Downloaded: 2020-W48.pdf
# SN 257: Downloading 2020-W49.pdf - An update of Lassa fever outbreak in Nigeria for Week 49
# ✓ Downloaded: 2020-W49.pdf
# SN 256: Downloading 2020-W50.pdf - An update of Lassa fever outbreak in Nigeria for Week 50
# ✓ Downloaded: 2020-W50.pdf
# SN 255: Downloading 2020-W51.pdf - An update of Lassa fever outbreak in Nigeria for Week 51
# ✓ Downloaded: 2020-W51.pdf
# SN 254: Downloading 2020-W52.pdf - An update of Lassa fever outbreak in Nigeria for Week 52
# ✓ Downloaded: 2020-W52.pdf
# SN 253: Downloading 2020-W53.pdf - An update of Lassa fever outbreak in Nigeria for Week 53
# ✓ Downloaded: 2020-W53.pdf
# SN 252: Downloading 2021-W01.pdf - An update of Lassa fever outbreak in Nigeria for Week 1
# ✓ Downloaded: 2021-W01.pdf
# SN 251: Downloading 2021-W02.pdf - An update of Lassa fever outbreak in Nigeria for Week 2
# ✓ Downloaded: 2021-W02.pdf
# SN 250: Downloading 2021-W03.pdf - An update of Lassa fever outbreak in Nigeria for Week 3
# ✓ Downloaded: 2021-W03.pdf
# SN 249: Downloading 2021-W04.pdf - An update of Lassa fever outbreak in Nigeria for Week 4
# ✓ Downloaded: 2021-W04.pdf
# SN 248: Downloading 2021-W05.pdf - An update of Lassa fever outbreak in Nigeria for Week 5
# ✓ Downloaded: 2021-W05.pdf
# SN 247: Downloading 2021-W06.pdf - An update of Lassa fever outbreak in Nigeria for Week 6
# ✓ Downloaded: 2021-W06.pdf
# SN 246: Downloading 2021-W07.pdf - An update of Lassa fever outbreak in Nigeria for Week 7
# ✓ Downloaded: 2021-W07.pdf
# SN 245: Downloading 2021-W08.pdf - An update of Lassa fever outbreak in Nigeria for Week 8
# ✓ Downloaded: 2021-W08.pdf
# SN 244: Downloading 2021-W09.pdf - An update of Lassa fever outbreak in Nigeria for Week 9
# ✓ Downloaded: 2021-W09.pdf
# SN 243: Downloading 2021-W10.pdf - An update of Lassa fever outbreak in Nigeria for Week 10
# ✓ Downloaded: 2021-W10.pdf
# SN 242: Downloading 2021-W11.pdf - An update of Lassa fever outbreak in Nigeria for Week 11
# ✓ Downloaded: 2021-W11.pdf
# SN 241: Downloading 2021-W12.pdf - An update of Lassa fever outbreak in Nigeria for Week 12
# ✓ Downloaded: 2021-W12.pdf
# SN 240: Downloading 2021-W13.pdf - An update of Lassa fever outbreak in Nigeria for Week 13
# ✓ Downloaded: 2021-W13.pdf
# SN 239: Downloading 2021-W14.pdf - An update of Lassa fever outbreak in Nigeria for Week 14
# ✓ Downloaded: 2021-W14.pdf
# SN 238: Downloading 2021-W15.pdf - An update of Lassa fever outbreak in Nigeria for Week 15
# ✓ Downloaded: 2021-W15.pdf
# SN 237: Downloading 2021-W16.pdf - An update of Lassa fever outbreak in Nigeria for Week 16
# ✓ Downloaded: 2021-W16.pdf
# SN 236: Downloading 2021-W17.pdf - An update of Lassa fever outbreak in Nigeria for Week 17
# ✓ Downloaded: 2021-W17.pdf
# SN 235: Downloading 2021-W18.pdf - An update of Lassa fever outbreak in Nigeria for Week 18
# ✓ Downloaded: 2021-W18.pdf
# SN 234: Downloading 2021-W19.pdf - An update of Lassa fever outbreak in Nigeria for Week 19
# ✓ Downloaded: 2021-W19.pdf
# SN 233: Downloading 2021-W20.pdf - An update of Lassa fever outbreak in Nigeria for Week 20
# ✓ Downloaded: 2021-W20.pdf
# SN 232: Downloading 2021-W21.pdf - An update of Lassa fever outbreak in Nigeria for Week 21
# ✓ Downloaded: 2021-W21.pdf
# SN 231: Downloading 2021-W22.pdf - An update of Lassa fever outbreak in Nigeria for Week 22
# ✓ Downloaded: 2021-W22.pdf
# SN 230: Downloading 2021-W23.pdf - An update of Lassa fever outbreak in Nigeria for Week 23
# ✓ Downloaded: 2021-W23.pdf
# SN 229: Downloading 2021-W24.pdf - An update of Lassa fever outbreak in Nigeria for Week 24
# ✗ Failed to download 2021-W24.pdf: 404 Client Error: Not Found for url: https://ncdc.gov.ng/themes/common/files/sitreps/c961c37b5cf7d7f010f0b991722f89ba.pdf
# SN 228: Downloading 2021-W25.pdf - An update of Lassa fever outbreak in Nigeria for Week 25
# ✓ Downloaded: 2021-W25.pdf
# SN 227: Downloading 2021-W26.pdf - An update of Lassa fever outbreak in Nigeria for Week 26
# ✓ Downloaded: 2021-W26.pdf
# SN 226: Downloading 2021-W27.pdf - An update of Lassa fever outbreak in Nigeria for Week 27
# ✓ Downloaded: 2021-W27.pdf
# SN 225: Downloading 2021-W28.pdf - An update of Lassa fever outbreak in Nigeria for Week 28
# ✓ Downloaded: 2021-W28.pdf
# SN 224: Downloading 2021-W29.pdf - An update of Lassa fever outbreak in Nigeria for Week 29
# ✓ Downloaded: 2021-W29.pdf
# SN 223: Downloading 2021-W30.pdf - An update of Lassa fever outbreak in Nigeria for Week 30
# ✓ Downloaded: 2021-W30.pdf
# SN 222: Downloading 2021-W31.pdf - An update of Lassa fever outbreak in Nigeria for Week 31
# ✓ Downloaded: 2021-W31.pdf
# SN 221: Downloading 2021-W32.pdf - An update of Lassa fever outbreak in Nigeria for Week 32
# ✓ Downloaded: 2021-W32.pdf
# SN 220: Downloading 2021-W33.pdf - An update of Lassa fever outbreak in Nigeria for Week 33
# ✓ Downloaded: 2021-W33.pdf
# SN 219: Downloading 2021-W34.pdf - An update of Lassa fever outbreak in Nigeria for Week 34
# ✓ Downloaded: 2021-W34.pdf
# SN 218: Downloading 2021-W35.pdf - An update of Lassa fever outbreak in Nigeria for Week 35
# ✓ Downloaded: 2021-W35.pdf
# SN 217: Downloading 2021-W36.pdf - An update of Lassa fever outbreak in Nigeria for Week 36
# ✓ Downloaded: 2021-W36.pdf
# SN 216: Downloading 2021-W37.pdf - An update of Lassa fever outbreak in Nigeria for Week 37
# ✓ Downloaded: 2021-W37.pdf
# SN 215: Downloading 2021-W38.pdf - An update of Lassa fever outbreak in Nigeria for Week 38
# ✓ Downloaded: 2021-W38.pdf
# SN 214: Downloading 2021-W39.pdf - An update of Lassa fever outbreak in Nigeria for Week 39
# ✓ Downloaded: 2021-W39.pdf
# SN 213: Downloading 2021-W40.pdf - An update of Lassa fever outbreak in Nigeria for Week 40
# ✓ Downloaded: 2021-W40.pdf
# SN 212: Downloading 2021-W41.pdf - An update of Lassa fever outbreak in Nigeria for Week 41
# ✓ Downloaded: 2021-W41.pdf
# SN 211: Downloading 2021-W42.pdf - An update of Lassa fever outbreak in Nigeria for Week 42
# ✓ Downloaded: 2021-W42.pdf
# SN 210: Downloading 2021-W43.pdf - An update of Lassa fever outbreak in Nigeria for Week 43
# ✓ Downloaded: 2021-W43.pdf
# SN 209: Downloading 2021-W44.pdf - An update of Lassa fever outbreak in Nigeria for Week 44
# ✓ Downloaded: 2021-W44.pdf
# SN 208: Downloading 2021-W45.pdf - An update of Lassa fever outbreak in Nigeria for Week 45
# ✓ Downloaded: 2021-W45.pdf
# SN 207: Downloading 2021-W46.pdf - An update of Lassa fever outbreak in Nigeria for Week 46
# ✓ Downloaded: 2021-W46.pdf
# SN 206: Downloading 2021-W47.pdf - An update of Lassa fever outbreak in Nigeria for Week 47
# ✓ Downloaded: 2021-W47.pdf
# SN 205: Downloading 2021-W48.pdf - An update of Lassa fever outbreak in Nigeria for Week 48
# ✓ Downloaded: 2021-W48.pdf
# SN 204: Downloading 2021-W49.pdf - An update of Lassa fever outbreak in Nigeria for Week 49
# ✓ Downloaded: 2021-W49.pdf
# SN 203: Downloading 2021-W50.pdf - An update of Lassa fever outbreak in Nigeria for Week 50
# ✓ Downloaded: 2021-W50.pdf
# SN 202: Downloading 2021-W51.pdf - An update of Lassa fever outbreak in Nigeria for Week 51
# ✓ Downloaded: 2021-W51.pdf
# SN 201: Downloading 2021-W52.pdf - An update of Lassa fever outbreak in Nigeria for Week 52
# ✓ Downloaded: 2021-W52.pdf
# SN 200: Downloading 2021-W53.pdf - An update of Lassa fever outbreak in Nigeria for Week 1
# ✓ Downloaded: 2021-W53.pdf
# SN 199: Downloading 2022-W01.pdf - An update of Lassa fever outbreak in Nigeria for Week 2
# ✓ Downloaded: 2022-W01.pdf
# SN 198: Downloading 2022-W02.pdf - An update of Lassa fever outbreak in Nigeria for Week 3
# ✓ Downloaded: 2022-W02.pdf
# SN 197: Downloading 2022-W03.pdf - An update of Lassa fever outbreak in Nigeria for Week 4
# ✓ Downloaded: 2022-W03.pdf
# SN 196: Downloading 2022-W04.pdf - An update of Lassa fever outbreak in Nigeria for Week 5
# ✓ Downloaded: 2022-W04.pdf
# SN 195: Downloading 2022-W05.pdf - An update of Lassa fever outbreak in Nigeria for Week 6
# ✓ Downloaded: 2022-W05.pdf
# SN 194: Downloading 2022-W06.pdf - An update of Lassa fever outbreak in Nigeria for Week 7
# ✓ Downloaded: 2022-W06.pdf
# SN 193: Downloading 2022-W07.pdf - An update of Lassa fever outbreak in Nigeria for Week 8
# ✓ Downloaded: 2022-W07.pdf
# SN 192: Downloading 2022-W08.pdf - An update of Lassa fever outbreak in Nigeria for Week 9
# ✓ Downloaded: 2022-W08.pdf
# SN 191: Downloading 2022-W09.pdf - An update of Lassa fever outbreak in Nigeria for Week 10
# ✓ Downloaded: 2022-W09.pdf
# SN 190: Downloading 2022-W10.pdf - An update of Lassa fever outbreak in Nigeria for Week 11
# ✓ Downloaded: 2022-W10.pdf
# SN 189: Downloading 2022-W11.pdf - An update of Lassa fever outbreak in Nigeria for Week 12
# ✓ Downloaded: 2022-W11.pdf
# SN 188: Downloading 2022-W12.pdf - An update of Lassa fever outbreak in Nigeria for Week 13
# ✓ Downloaded: 2022-W12.pdf
# SN 187: Downloading 2022-W13.pdf - An update of Lassa fever outbreak in Nigeria for Week 14
# ✓ Downloaded: 2022-W13.pdf
# SN 186: Downloading 2022-W14.pdf - An update of Lassa fever outbreak in Nigeria for Week 15
# ✓ Downloaded: 2022-W14.pdf
# SN 185: Downloading 2022-W15.pdf - An update of Lassa fever outbreak in Nigeria for Week 16
# ✓ Downloaded: 2022-W15.pdf
# SN 184: Downloading 2022-W16.pdf - An update of Lassa fever outbreak in Nigeria for Week 17
# ✓ Downloaded: 2022-W16.pdf
# SN 183: Downloading 2022-W17.pdf - An update of Lassa fever outbreak in Nigeria for Week 18
# ✓ Downloaded: 2022-W17.pdf
# SN 182: Downloading 2022-W18.pdf - An update of Lassa fever outbreak in Nigeria for Week 19
# ✓ Downloaded: 2022-W18.pdf
# SN 181: Downloading 2022-W19.pdf - An update of Lassa fever outbreak in Nigeria for Week 20
# ✓ Downloaded: 2022-W19.pdf
# SN 180: Downloading 2022-W20.pdf - An update of Lassa fever outbreak in Nigeria for Week 21
# ✗ Failed to download 2022-W20.pdf: 404 Client Error: Not Found for url: https://ncdc.gov.ng/themes/common/files/sitreps/6ce166b15bffc6986d356448d48d6a34.pdf
# SN 179: Downloading 2022-W21.pdf - An update of Lassa fever outbreak in Nigeria for Week 23
# ✓ Downloaded: 2022-W21.pdf
# SN 178: Downloading 2022-W22.pdf - An update of Lassa fever outbreak in Nigeria for Week 24
# ✓ Downloaded: 2022-W22.pdf
# SN 177: Downloading 2022-W23.pdf - An update of Lassa fever outbreak in Nigeria for Week 25
# ✓ Downloaded: 2022-W23.pdf
# SN 176: Downloading 2022-W24.pdf - An update of Lassa fever outbreak in Nigeria for Week 26
# ✓ Downloaded: 2022-W24.pdf
# SN 175: Downloading 2022-W25.pdf - An update of Lassa fever outbreak in Nigeria for Week 27
# ✓ Downloaded: 2022-W25.pdf
# SN 174: Downloading 2022-W26.pdf - An update of Lassa fever outbreak in Nigeria for Week 28
# ✓ Downloaded: 2022-W26.pdf
# SN 173: Downloading 2022-W27.pdf - An update of Lassa fever outbreak in Nigeria for Week 29
# ✓ Downloaded: 2022-W27.pdf
# SN 172: Downloading 2022-W28.pdf - An update of Lassa fever outbreak in Nigeria for Week 30
# ✓ Downloaded: 2022-W28.pdf
# SN 171: Downloading 2022-W29.pdf - An update of Lassa fever outbreak in Nigeria for Week 31
# ✓ Downloaded: 2022-W29.pdf
# SN 170: Downloading 2022-W30.pdf - An update of Lassa fever outbreak in Nigeria for Week 32
# ✓ Downloaded: 2022-W30.pdf
# SN 169: Downloading 2022-W31.pdf - An update of Lassa fever outbreak in Nigeria for Week 33
# ✓ Downloaded: 2022-W31.pdf
# SN 168: Downloading 2022-W32.pdf - An update of Lassa fever outbreak in Nigeria for Week 34
# ✓ Downloaded: 2022-W32.pdf
# SN 167: Downloading 2022-W33.pdf - An update of Lassa fever outbreak in Nigeria for Week 35
# ✓ Downloaded: 2022-W33.pdf
# SN 166: Downloading 2022-W34.pdf - An update of Lassa fever outbreak in Nigeria for Week 36
# ✓ Downloaded: 2022-W34.pdf
# SN 165: Downloading 2022-W35.pdf - An update of Lassa fever outbreak in Nigeria for Week 37
# ✓ Downloaded: 2022-W35.pdf
# SN 164: Downloading 2022-W36.pdf - An update of Lassa fever outbreak in Nigeria for Week 38
# ✓ Downloaded: 2022-W36.pdf
# SN 163: Downloading 2022-W37.pdf - An update of Lassa fever outbreak in Nigeria for Week 39
# ✓ Downloaded: 2022-W37.pdf
# SN 162: Downloading 2022-W38.pdf - An update of Lassa fever outbreak in Nigeria for Week 40
# ✓ Downloaded: 2022-W38.pdf
# SN 161: Downloading 2022-W39.pdf - An update of Lassa fever outbreak in Nigeria for Week 41
# ✓ Downloaded: 2022-W39.pdf
# SN 160: Downloading 2022-W40.pdf - An update of Lassa fever outbreak in Nigeria for Week 42
# ✓ Downloaded: 2022-W40.pdf
# SN 159: Downloading 2022-W41.pdf - An update of Lassa fever outbreak in Nigeria for Week 43
# ✓ Downloaded: 2022-W41.pdf
# SN 158: Downloading 2022-W42.pdf - An update of Lassa fever outbreak in Nigeria for Week 44
# ✓ Downloaded: 2022-W42.pdf
# SN 157: Downloading 2022-W43.pdf - An update of Lassa fever outbreak in Nigeria for Week 45
# ✓ Downloaded: 2022-W43.pdf
# SN 156: Downloading 2022-W44.pdf - An update of Lassa fever outbreak in Nigeria for Week 46
# ✓ Downloaded: 2022-W44.pdf
# SN 155: Downloading 2022-W45.pdf - An update of Lassa fever outbreak in Nigeria for Week 47
# ✓ Downloaded: 2022-W45.pdf
# SN 154: Downloading 2022-W46.pdf - An update of Lassa fever outbreak in Nigeria for Week 48
# ✓ Downloaded: 2022-W46.pdf
# SN 153: Downloading 2022-W47.pdf - An update of Lassa fever outbreak in Nigeria for Week 49
# ✓ Downloaded: 2022-W47.pdf
# SN 152: Downloading 2022-W48.pdf - An update of Lassa fever outbreak in Nigeria for Week 50
# ✓ Downloaded: 2022-W48.pdf
# SN 151: Downloading 2022-W49.pdf - An update of Lassa fever outbreak in Nigeria for Week 51
# ✓ Downloaded: 2022-W49.pdf
# SN 150: Downloading 2022-W50.pdf - An update of Lassa fever outbreak in Nigeria for Week 52
# ✓ Downloaded: 2022-W50.pdf
# SN 149: Downloading 2022-W51.pdf - An update of Lassa fever outbreak in Nigeria for Week 53
# ✓ Downloaded: 2022-W51.pdf
# SN 148: Downloading 2022-W52.pdf - An update of Lassa fever outbreak in Nigeria for Week 2
# ✓ Downloaded: 2022-W52.pdf
# SN 147: Downloading 2022-W53.pdf - An update of Lassa fever outbreak in Nigeria for Week 3
# ✓ Downloaded: 2022-W53.pdf
# SN 146: Downloading 2023-W01.pdf - An update of Lassa fever outbreak in Nigeria for Week 4
# ✓ Downloaded: 2023-W01.pdf
# SN 145: Downloading 2023-W02.pdf - An update of Lassa fever outbreak in Nigeria for Week 5
# ✓ Downloaded: 2023-W02.pdf
# SN 144: Downloading 2023-W03.pdf - An update of Lassa fever outbreak in Nigeria for Week 6
# ✓ Downloaded: 2023-W03.pdf
# SN 143: Downloading 2023-W04.pdf - An update of Lassa fever outbreak in Nigeria for Week 7
# ✓ Downloaded: 2023-W04.pdf
# SN 142: Downloading 2023-W05.pdf - An update of Lassa fever outbreak in Nigeria for Week 8
# ✓ Downloaded: 2023-W05.pdf
# SN 141: Downloading 2023-W06.pdf - An update of Lassa fever outbreak in Nigeria for Week 9
# ✓ Downloaded: 2023-W06.pdf
# SN 140: Downloading 2023-W07.pdf - An update of Lassa fever outbreak in Nigeria for Week 10
# ✓ Downloaded: 2023-W07.pdf
# SN 139: Downloading 2023-W08.pdf - An update of Lassa fever outbreak in Nigeria for Week 11
# ✓ Downloaded: 2023-W08.pdf
# SN 138: Downloading 2023-W09.pdf - An update of Lassa fever outbreak in Nigeria for Week 12
# ✓ Downloaded: 2023-W09.pdf
# SN 137: Downloading 2023-W10.pdf - An update of Lassa fever outbreak in Nigeria for Week 13
# ✓ Downloaded: 2023-W10.pdf
# SN 136: Downloading 2023-W11.pdf - An update of Lassa fever outbreak in Nigeria for Week 14
# ✓ Downloaded: 2023-W11.pdf
# SN 135: Downloading 2023-W12.pdf - An update of Lassa fever outbreak in Nigeria for Week 15
# ✓ Downloaded: 2023-W12.pdf
# SN 134: Downloading 2023-W13.pdf - An update of Lassa fever outbreak in Nigeria for Week 16
# ✓ Downloaded: 2023-W13.pdf
# SN 133: Downloading 2023-W14.pdf - An update of Lassa fever outbreak in Nigeria for Week 17
# ✓ Downloaded: 2023-W14.pdf
# SN 132: Downloading 2023-W15.pdf - An update of Lassa fever outbreak in Nigeria for Week 18
# ✓ Downloaded: 2023-W15.pdf
# SN 131: Downloading 2023-W16.pdf - An update of Lassa fever outbreak in Nigeria for Week 19
# ✓ Downloaded: 2023-W16.pdf
# SN 130: Downloading 2023-W17.pdf - An update of Lassa fever outbreak in Nigeria for Week 20
# ✓ Downloaded: 2023-W17.pdf
# SN 129: Downloading 2023-W18.pdf - An update of Lassa fever outbreak in Nigeria for Week 21
# ✓ Downloaded: 2023-W18.pdf
# SN 128: Downloading 2023-W19.pdf - An update of Lassa fever outbreak in Nigeria for Week 22
# ✓ Downloaded: 2023-W19.pdf
# SN 127: Downloading 2023-W20.pdf - An update of Lassa fever outbreak in Nigeria for Week 23
# ✓ Downloaded: 2023-W20.pdf
# SN 126: Downloading 2023-W21.pdf - An update of Lassa fever outbreak in Nigeria for Week 24
# ✓ Downloaded: 2023-W21.pdf
# SN 125: Downloading 2023-W22.pdf - An update of Lassa fever outbreak in Nigeria for Week 25
# ✓ Downloaded: 2023-W22.pdf
# SN 124: Downloading 2023-W23.pdf - An update of Lassa fever outbreak in Nigeria for Week 26
# ✓ Downloaded: 2023-W23.pdf
# SN 123: Downloading 2023-W24.pdf - An update of Lassa fever outbreak in Nigeria for Week 27
# ✓ Downloaded: 2023-W24.pdf
# SN 122: Downloading 2023-W25.pdf - An update of Lassa fever outbreak in Nigeria for Week 28
# ✓ Downloaded: 2023-W25.pdf
# SN 121: Downloading 2023-W26.pdf - An update of Lassa fever outbreak in Nigeria for Week 29
# ✓ Downloaded: 2023-W26.pdf
# SN 120: Downloading 2023-W27.pdf - An update of Lassa fever outbreak in Nigeria for Week 30
# ✓ Downloaded: 2023-W27.pdf
# SN 119: Downloading 2023-W28.pdf - An update of Lassa fever outbreak in Nigeria for Week 31
# ✓ Downloaded: 2023-W28.pdf
# SN 118: Downloading 2023-W29.pdf - An update of Lassa fever outbreak in Nigeria for Week 32
# ✓ Downloaded: 2023-W29.pdf
# SN 117: Downloading 2023-W30.pdf - An update of Lassa fever outbreak in Nigeria for Week 33
# ✓ Downloaded: 2023-W30.pdf
# SN 116: Downloading 2023-W31.pdf - An update of Lassa fever outbreak in Nigeria for Week 34
# ✓ Downloaded: 2023-W31.pdf
# SN 115: Downloading 2023-W32.pdf - An update of Lassa fever outbreak in Nigeria for Week 35
# ✓ Downloaded: 2023-W32.pdf
# SN 114: Downloading 2023-W33.pdf - An update of Lassa fever outbreak in Nigeria for Week 36
# ✓ Downloaded: 2023-W33.pdf
# SN 113: Downloading 2023-W34.pdf - An update of Lassa fever outbreak in Nigeria for Week 37
# ✓ Downloaded: 2023-W34.pdf
# SN 112: Downloading 2023-W35.pdf - An update of Lassa fever outbreak in Nigeria for Week 38
# ✗ Failed to download 2023-W35.pdf: 404 Client Error: Not Found for url: https://ncdc.gov.ng/themes/common/files/sitreps/7bff918b81a8e610200b879d929995da.pdf
# SN 111: Downloading 2023-W36.pdf - An update of Lassa fever outbreak in Nigeria for Week 39
# ✓ Downloaded: 2023-W36.pdf
# SN 110: Downloading 2023-W37.pdf - An update of Lassa fever outbreak in Nigeria for Week 40
# ✓ Downloaded: 2023-W37.pdf
# SN 109: Downloading 2023-W38.pdf - An update of Lassa fever outbreak in Nigeria for Week 41
# ✓ Downloaded: 2023-W38.pdf
# SN 108: Downloading 2023-W39.pdf - An update of Lassa fever outbreak in Nigeria for Week 42
# ✓ Downloaded: 2023-W39.pdf
# SN 107: Downloading 2023-W40.pdf - An update of Lassa fever outbreak in Nigeria for Week 43
# ✓ Downloaded: 2023-W40.pdf
# SN 106: Downloading 2023-W41.pdf - An update of Lassa fever outbreak in Nigeria for Week 44
# ✓ Downloaded: 2023-W41.pdf
# SN 105: Downloading 2023-W42.pdf - An update of Lassa fever outbreak in Nigeria for Week 45
# ✓ Downloaded: 2023-W42.pdf
# SN 104: Downloading 2023-W43.pdf - An update of Lassa fever outbreak in Nigeria for Week 46
# ✓ Downloaded: 2023-W43.pdf
# SN 103: Downloading 2023-W44.pdf - An update of Lassa fever outbreak in Nigeria for Week 47
# ✓ Downloaded: 2023-W44.pdf
# SN 102: Downloading 2023-W45.pdf - An update of Lassa fever outbreak in Nigeria for Week 48
# ✓ Downloaded: 2023-W45.pdf
# SN 101: Downloading 2023-W46.pdf - An update of Lassa fever outbreak in Nigeria for Week 49
# ✓ Downloaded: 2023-W46.pdf
# SN 100: Downloading 2023-W47.pdf - An update of Lassa fever outbreak in Nigeria for Week 50
# ✓ Downloaded: 2023-W47.pdf
# SN 99: Downloading 2023-W48.pdf - An update of Lassa fever outbreak in Nigeria for Week 51
# ✓ Downloaded: 2023-W48.pdf
# SN 98: Downloading 2023-W49.pdf - An update of Lassa fever outbreak in Nigeria for Week 52
# ✓ Downloaded: 2023-W49.pdf
# SN 97: Downloading 2023-W50.pdf - An update of Lassa fever outbreak in Nigeria for Week 1
# ✓ Downloaded: 2023-W50.pdf
# SN 96: Downloading 2023-W51.pdf - An update of Lassa fever outbreak in Nigeria for Week 2
# ✓ Downloaded: 2023-W51.pdf
# SN 95: Downloading 2023-W52.pdf - An update of Lassa fever outbreak in Nigeria for Week 3
# ✓ Downloaded: 2023-W52.pdf
# SN 94: Downloading 2023-W53.pdf - An update of Lassa fever outbreak in Nigeria for Week 4
# ✓ Downloaded: 2023-W53.pdf
# SN 93: Downloading 2024-W01.pdf - An update of Lassa fever outbreak in Nigeria for Week 5
# ✓ Downloaded: 2024-W01.pdf
# SN 92: Downloading 2024-W02.pdf - An update of Lassa fever outbreak in Nigeria for Week 6
# ✓ Downloaded: 2024-W02.pdf
# SN 91: Downloading 2024-W03.pdf - An update of Lassa fever outbreak in Nigeria for Week 7
# ✓ Downloaded: 2024-W03.pdf
# SN 90: Downloading 2024-W04.pdf - An update of Lassa fever outbreak in Nigeria for Week 8
# ✓ Downloaded: 2024-W04.pdf
# SN 89: Downloading 2024-W05.pdf - An update of Lassa fever outbreak in Nigeria for Week 9
# ✓ Downloaded: 2024-W05.pdf
# SN 88: Downloading 2024-W06.pdf - An update of Lassa fever outbreak in Nigeria for Week 10
# ✓ Downloaded: 2024-W06.pdf
# SN 87: Downloading 2024-W07.pdf - An update of Lassa fever outbreak in Nigeria for Week 11
# ✓ Downloaded: 2024-W07.pdf
# SN 86: Downloading 2024-W08.pdf - An update of Lassa fever outbreak in Nigeria for Week 12
# ✓ Downloaded: 2024-W08.pdf
# SN 85: Downloading 2024-W09.pdf - An update of Lassa fever outbreak in Nigeria for Week 13
# ✓ Downloaded: 2024-W09.pdf
# SN 84: Downloading 2024-W10.pdf - An update of Lassa fever outbreak in Nigeria for Week 14
# ✓ Downloaded: 2024-W10.pdf
# SN 83: Downloading 2024-W11.pdf - An update of Lassa fever outbreak in Nigeria for Week 15
# ✓ Downloaded: 2024-W11.pdf
# SN 82: Downloading 2024-W12.pdf - An update of Lassa fever outbreak in Nigeria for Week 16
# ✓ Downloaded: 2024-W12.pdf
# SN 81: Downloading 2024-W13.pdf - An update of Lassa fever outbreak in Nigeria for Week 17
# ✓ Downloaded: 2024-W13.pdf
# SN 80: Downloading 2024-W14.pdf - An update of Lassa fever outbreak in Nigeria for Week 18
# ✓ Downloaded: 2024-W14.pdf
# SN 79: Downloading 2024-W15.pdf - An update of Lassa fever outbreak in Nigeria for Week 19
# ✓ Downloaded: 2024-W15.pdf
# SN 78: Downloading 2024-W16.pdf - An update of Lassa fever outbreak in Nigeria for Week 20
# ✓ Downloaded: 2024-W16.pdf
# SN 77: Downloading 2024-W17.pdf - An update of Lassa fever outbreak in Nigeria for Week 21
# ✓ Downloaded: 2024-W17.pdf
# SN 76: Downloading 2024-W18.pdf - An update of Lassa fever outbreak in Nigeria for Week 22
# ✓ Downloaded: 2024-W18.pdf
# SN 75: Downloading 2024-W19.pdf - An update of Lassa fever outbreak in Nigeria for Week 23
# ✓ Downloaded: 2024-W19.pdf
# SN 74: Downloading 2024-W20.pdf - An update of Lassa fever outbreak in Nigeria for Week 24
# ✓ Downloaded: 2024-W20.pdf
# SN 73: Downloading 2024-W21.pdf - An update of Lassa fever outbreak in Nigeria for Week 25
# ✓ Downloaded: 2024-W21.pdf
# SN 72: Downloading 2024-W22.pdf - An update of Lassa fever outbreak in Nigeria for Week 26
# ✓ Downloaded: 2024-W22.pdf
# SN 71: Downloading 2024-W23.pdf - An update of Lassa fever outbreak in Nigeria for Week 27
# ✓ Downloaded: 2024-W23.pdf
# SN 70: Downloading 2024-W24.pdf - An update of Lassa fever outbreak in Nigeria for Week 28
# ✓ Downloaded: 2024-W24.pdf
# SN 69: Downloading 2024-W25.pdf - An update of Lassa fever outbreak in Nigeria for Week 29
# ✓ Downloaded: 2024-W25.pdf
# SN 68: Downloading 2024-W26.pdf - An update of Lassa fever outbreak in Nigeria for Week 30
# ✓ Downloaded: 2024-W26.pdf
# SN 67: Downloading 2024-W27.pdf - An update of Lassa fever outbreak in Nigeria for Week 31
# ✓ Downloaded: 2024-W27.pdf
# SN 66: Downloading 2024-W28.pdf - An update of Lassa fever outbreak in Nigeria for Week 32
# ✓ Downloaded: 2024-W28.pdf
# SN 65: Downloading 2024-W29.pdf - An update of Lassa fever outbreak in Nigeria for Week 33
# ✓ Downloaded: 2024-W29.pdf
# SN 64: Downloading 2024-W30.pdf - An update of Lassa fever outbreak in Nigeria for Week 34
# ✓ Downloaded: 2024-W30.pdf
# SN 63: Downloading 2024-W31.pdf - An update of Lassa fever outbreak in Nigeria for Week 35
# ✓ Downloaded: 2024-W31.pdf
# SN 62: Downloading 2024-W32.pdf - An update of Lassa fever outbreak in Nigeria for Week 36
# ✓ Downloaded: 2024-W32.pdf
# SN 61: Downloading 2024-W33.pdf - An update of Lassa fever outbreak in Nigeria for Week 37
# ✓ Downloaded: 2024-W33.pdf
# SN 60: Downloading 2024-W34.pdf - An update of Lassa fever outbreak in Nigeria for Week 38
# ✓ Downloaded: 2024-W34.pdf
# SN 59: Downloading 2024-W35.pdf - An update of Lassa fever outbreak in Nigeria for Week 39
# ✓ Downloaded: 2024-W35.pdf
# SN 58: Downloading 2024-W36.pdf - An update of Lassa fever outbreak in Nigeria for Week 40
# ✓ Downloaded: 2024-W36.pdf
# SN 57: Downloading 2024-W37.pdf - An update of Lassa fever outbreak in Nigeria for Week 41
# ✓ Downloaded: 2024-W37.pdf
# SN 56: Downloading 2024-W38.pdf - An update of Lassa fever outbreak in Nigeria for Week 42
# ✓ Downloaded: 2024-W38.pdf
# SN 55: Downloading 2024-W39.pdf - An update of Lassa fever outbreak in Nigeria for Week 43
# ✓ Downloaded: 2024-W39.pdf
# SN 54: Downloading 2024-W40.pdf - An update of Lassa fever outbreak in Nigeria for Week 44
# ✓ Downloaded: 2024-W40.pdf
# SN 53: Downloading 2024-W41.pdf - An update of Lassa fever outbreak in Nigeria for Week 45
# ✓ Downloaded: 2024-W41.pdf
# SN 52: Downloading 2024-W42.pdf - An update of Lassa fever outbreak in Nigeria for Week 46
# ✓ Downloaded: 2024-W42.pdf
# SN 51: Downloading 2024-W43.pdf - An update of Lassa fever outbreak in Nigeria for Week 47
# ✓ Downloaded: 2024-W43.pdf
# SN 50: Downloading 2024-W44.pdf - An update of Lassa fever outbreak in Nigeria for Week 48
# ✓ Downloaded: 2024-W44.pdf
# SN 49: Downloading 2024-W45.pdf - An update of Lassa fever outbreak in Nigeria for Week 49
# ✓ Downloaded: 2024-W45.pdf
# SN 48: Downloading 2024-W46.pdf - An update of Lassa fever outbreak in Nigeria for Week 50
# ✓ Downloaded: 2024-W46.pdf
# SN 47: Downloading 2024-W47.pdf - An update of Lassa fever outbreak in Nigeria for Week 51
# ✓ Downloaded: 2024-W47.pdf
# SN 46: Downloading 2024-W48.pdf - An update of Lassa fever outbreak in Nigeria for Week 52
# ✓ Downloaded: 2024-W48.pdf
# SN 45: Downloading 2024-W49.pdf - An update of Lassa fever outbreak in Nigeria for Week 1
# ✓ Downloaded: 2024-W49.pdf
# SN 44: Downloading 2024-W50.pdf - An update of Lassa fever outbreak in Nigeria for Week 2
# ✓ Downloaded: 2024-W50.pdf
# SN 43: Downloading 2024-W51.pdf - An update of Lassa fever outbreak in Nigeria for Week 3
# ✓ Downloaded: 2024-W51.pdf
# SN 42: Downloading 2024-W52.pdf - An update of Lassa fever outbreak in Nigeria for Week 4
# ✓ Downloaded: 2024-W52.pdf
# SN 41: Downloading 2024-W53.pdf - An update of Lassa fever outbreak in Nigeria for Week 5
# ✓ Downloaded: 2024-W53.pdf
# SN 40: Downloading 2025-W01.pdf - An update of Lassa fever outbreak in Nigeria for Week 6
# ✓ Downloaded: 2025-W01.pdf
# SN 39: Downloading 2025-W02.pdf - An update of Lassa fever outbreak in Nigeria for Week 7
# ✓ Downloaded: 2025-W02.pdf
# SN 38: Downloading 2025-W03.pdf - An update of Lassa fever outbreak in Nigeria for Week 8
# ✓ Downloaded: 2025-W03.pdf
# SN 37: Downloading 2025-W04.pdf - An update of Lassa fever outbreak in Nigeria for Week 9
# ✓ Downloaded: 2025-W04.pdf
# SN 36: Downloading 2025-W05.pdf - An update of Lassa fever outbreak in Nigeria for Week 10
# ✓ Downloaded: 2025-W05.pdf
# SN 35: Downloading 2025-W06.pdf - An update of Lassa fever outbreak in Nigeria for Week 11
# ✓ Downloaded: 2025-W06.pdf
# SN 34: Downloading 2025-W07.pdf - An update of Lassa fever outbreak in Nigeria for Week 12
# ✓ Downloaded: 2025-W07.pdf
# SN 33: Downloading 2025-W08.pdf - An update of Lassa fever outbreak in Nigeria for Week 13
# ✓ Downloaded: 2025-W08.pdf
# SN 32: Downloading 2025-W09.pdf - An update of Lassa fever outbreak in Nigeria for Week 14
# ✓ Downloaded: 2025-W09.pdf
# SN 31: Downloading 2025-W10.pdf - An update of Lassa fever outbreak in Nigeria for Week 15
# ✓ Downloaded: 2025-W10.pdf
# SN 30: Downloading 2025-W11.pdf - An update of Lassa fever outbreak in Nigeria for Week 16
# ✓ Downloaded: 2025-W11.pdf
# SN 29: Downloading 2025-W12.pdf - An update of Lassa fever outbreak in Nigeria for Week 17
# ✓ Downloaded: 2025-W12.pdf
# SN 28: Downloading 2025-W13.pdf - An update of Lassa fever outbreak in Nigeria for Week 18
# ✓ Downloaded: 2025-W13.pdf
# SN 27: Downloading 2025-W14.pdf - An update of Lassa fever outbreak in Nigeria for Week 19
# ✓ Downloaded: 2025-W14.pdf
# SN 26: Downloading 2025-W15.pdf - An update of Lassa fever outbreak in Nigeria for Week 20
# ✓ Downloaded: 2025-W15.pdf
# SN 25: Downloading 2025-W16.pdf - An update of Lassa fever outbreak in Nigeria for Week 21
# ✓ Downloaded: 2025-W16.pdf
# SN 24: Downloading 2025-W17.pdf - An update of Lassa fever outbreak in Nigeria for Week 22
# ✓ Downloaded: 2025-W17.pdf
# SN 23: Downloading 2025-W18.pdf - An update of Lassa fever outbreak in Nigeria for Week 23
# ✓ Downloaded: 2025-W18.pdf
# SN 22: Downloading 2025-W19.pdf - An update of Lassa fever outbreak in Nigeria for Week 24
# ✓ Downloaded: 2025-W19.pdf
# SN 21: Downloading 2025-W20.pdf - An update of Lassa fever outbreak in Nigeria for Week 25
# ✓ Downloaded: 2025-W20.pdf
# SN 20: Downloading 2025-W21.pdf - An update of Lassa fever outbreak in Nigeria for Week 26
# ✓ Downloaded: 2025-W21.pdf
# SN 19: Downloading 2025-W22.pdf - An update of Lassa fever outbreak in Nigeria for Week 27
# ✓ Downloaded: 2025-W22.pdf
# SN 18: Downloading 2025-W23.pdf - An update of Lassa fever outbreak in Nigeria for Week 28
# ✓ Downloaded: 2025-W23.pdf
# SN 17: Downloading 2025-W24.pdf - An update of Lassa fever outbreak in Nigeria for Week 29
# ✓ Downloaded: 2025-W24.pdf
# SN 16: Downloading 2025-W25.pdf - An update of Lassa fever outbreak in Nigeria for Week 30
# ✓ Downloaded: 2025-W25.pdf
# SN 15: Downloading 2025-W26.pdf - An update of Lassa fever outbreak in Nigeria for Week 31
# ✓ Downloaded: 2025-W26.pdf
# SN 14: Downloading 2025-W27.pdf - An update of Lassa fever outbreak in Nigeria for Week 32
# ✓ Downloaded: 2025-W27.pdf
# SN 13: Downloading 2025-W28.pdf - An update of Lassa fever outbreak in Nigeria for Week 33
# ✓ Downloaded: 2025-W28.pdf
# SN 12: Downloading 2025-W29.pdf - An update of Lassa fever outbreak in Nigeria for Week 34
# ✓ Downloaded: 2025-W29.pdf
# SN 11: Downloading 2025-W30.pdf - An update of Lassa fever outbreak in Nigeria for Week 35
# ✓ Downloaded: 2025-W30.pdf
# SN 10: Downloading 2025-W31.pdf - An update of Lassa fever outbreak in Nigeria for Week 36
# ✓ Downloaded: 2025-W31.pdf
# SN 9: Downloading 2025-W32.pdf - An update of Lassa fever outbreak in Nigeria for Week 37
# ✓ Downloaded: 2025-W32.pdf
# SN 8: Downloading 2025-W33.pdf - An update of Lassa fever outbreak in Nigeria for Week 38
# ✓ Downloaded: 2025-W33.pdf
# SN 7: Downloading 2025-W34.pdf - An update of Lassa fever outbreak in Nigeria for Week 39
# ✓ Downloaded: 2025-W34.pdf
# SN 6: Downloading 2025-W35.pdf - An update of Lassa fever outbreak in Nigeria for Week 40
# ✓ Downloaded: 2025-W35.pdf
# SN 5: Downloading 2025-W36.pdf - An update of Lassa fever outbreak in Nigeria for Week 41
# ✓ Downloaded: 2025-W36.pdf
# SN 4: Downloading 2025-W37.pdf - An update of Lassa fever outbreak in Nigeria for Week 42
# ✓ Downloaded: 2025-W37.pdf
# SN 3: Downloading 2025-W38.pdf - An update of Lassa fever outbreak in Nigeria for Week 43
# ✓ Downloaded: 2025-W38.pdf
# SN 2: Downloading 2025-W39.pdf - An update of Lassa fever outbreak in Nigeria for Week 44
# ✓ Downloaded: 2025-W39.pdf
# SN 1: Downloading 2025-W40.pdf - An update of Lassa fever outbreak in Nigeria for Week 45
# ✓ Downloaded: 2025-W40.pdf
#
# Processing complete!
# Files saved to: /kaggle/working/ncdc_reports

# %% [markdown]
# ## PDF Data Extraction

# %% [markdown]
# ### Helper Function Definition

# %%
# Helper functions for PDF creation and week calculations
def create_placeholder_pdf(filename: str, week_info: str):
    """
    Create a placeholder PDF for weeks with missing reports.
    
    Args:
        filename (str): Name to save the PDF as.
        week_info (str): Week information to display in the PDF.
    """
    pdf = FPDF()
    pdf.add_page()
    pdf.set_font("Arial", size=12)
    pdf.cell(200, 10, txt="Report Not Available", ln=1, align='C')
    pdf.cell(200, 10, txt=f"Week {week_info}", ln=1, align='C')
    pdf.cell(200, 10, txt="Placeholder for missing report", ln=1, align='C')
    pdf.output(os.path.join(SAVE_DIR, filename))  # save PDF


def get_week_year_from_sn(sn: int) -> tuple[int, int]:
    """
    Calculate ISO year and week number from serial number (SN).
    
    Args:
        sn (int): Serial number (week count)
    
    Returns:
        tuple[int, int]: (year, week) corresponding to the SN
    """
    weeks_passed = sn - START_SN  # difference from starting SN
    current_date = dt.datetime(START_YEAR, 1, 1)
    
    # Find the first Thursday of the year (ISO week rule)
    while current_date.weekday() != 3:  # 3 = Thursday
        current_date += dt.timedelta(days=1)
    
    # Add weeks passed to get target date
    target_date = current_date + dt.timedelta(weeks=weeks_passed)
    year = target_date.isocalendar()[0]
    week = target_date.isocalendar()[1]
    
    return year, week


def get_week_start_and_end_date(year: int, week: int) -> tuple[dt.datetime, dt.datetime]:
    """
    Calculate the start (Monday) and end (Sunday) dates of a given ISO week.
    
    Args:
        year (int): ISO year
        week (int): ISO week number
    
    Returns:
        tuple(datetime, datetime): (week_start, week_end)
    """
    # Get first day of the year
    first_jan = dt.datetime(year, 1, 1)
    
    # Find the first Thursday of the year (ISO week 1 contains Jan 4th)
    while first_jan.weekday() != 3:  # 3 = Thursday
        first_jan += dt.timedelta(days=1)
    
    # Calculate Monday of the ISO week
    week_start = first_jan + dt.timedelta(weeks=week-1) - dt.timedelta(days=3)
    week_end = week_start + dt.timedelta(days=6)  # Sunday of the same week
    
    return week_start, week_end

# %%
def extract_table_from_pdf(pdf_path: str) -> list:
    """
    Extract tables from the first page of a PDF and return their content.
    
    Args:
        pdf_path (str): Path to the PDF file.
    
    Returns:
        list: Extracted tables as lists of rows (each row is a list of cell values).
    """
    with pdfplumber.open(pdf_path) as pdf:
        page = pdf.pages[0]  # use first page
        
        # Settings to guide table extraction
        table_settings = {
            "vertical_strategy": "lines",         # use vertical lines for columns
            "horizontal_strategy": "lines",       # use horizontal lines for rows
            "explicit_vertical_lines": [],        # no manually specified vertical lines
            "explicit_horizontal_lines": [],      # no manually specified horizontal lines
            "snap_tolerance": 3,                  # tolerance for snapping edges
            "join_tolerance": 3,                  # tolerance for joining adjacent lines
            "edge_min_length": 3,                 # minimum line length to consider
            "min_words_vertical": 2,              # min words to form vertical segment
            "min_words_horizontal": 1,            # min words to form horizontal segment
        }
        
        tables = page.extract_tables(table_settings)  # extract tables
        return tables

# %%
def extract_case_data_from_table(data: list) -> Optional[Tuple[Any, Any, Any, Any]]:
    """
    Extract suspected, confirmed, probable cases, and deaths from a table.
    Searches for the row containing 'Current week' or 'Currentweek' and
    handles different table layouts.
    
    Args:
        data (list): Nested list representing the PDF table content.
    
    Returns:
        tuple or None: (suspected, confirmed, probable, deaths) if found, else None.
    """

    # --- recursive search for row containing "Current week" ---
    def search(lst: list) -> Optional[list]:
        for item in lst:
            if isinstance(item, list):
                found = search(item)
                if found:
                    return found
            elif isinstance(item, str) and ("Current week" in item or "Currentweek" in item):
                return lst
        return None

    row = search(data)
    
    # fallback for uncommon table patterns
    if not row:
        if len(data) == 5:
            try:
                section = data[3][6]
                return section[0], section[3], section[6], section[9]
            except Exception:
                return None
        return None

    # standard layout (row has consecutive values)
    if len(row) >= 5 and row[1] is not None:
        try:
            return row[1], row[2], row[3], row[4]
        except Exception:
            pass

    # sparse layout (values spread out across row)
    if len(row) >= 13:
        try:
            return row[3], row[6], row[9], row[12]
        except Exception:
            pass

    return None  # no valid data found

# %%
def extract_epi_week(pdf_path: str) -> Optional[str]:
    """
    Extract the Epi Week line from a PDF.
    Handles multiple formats by using regex patterns and checks first few pages.

    Args:
        pdf_path (str): Path to the PDF file.

    Returns:
        str or None: Extracted Epi Week string if found, else None.
    """
    # Patterns to match different Epi Week formats
    patterns = [
        r"EpiWeek\s*\d+:\s*\d+[–-]\d+[A-Za-z]+\d{4}",                        # Compressed format: "EpiWeek20:17–23May2021"
        r"Epi Week\s*\d+:\s*\d+(?:st|nd|rd|th)?\s*[–-]\s*\d+(?:st|nd|rd|th)?\s*[A-Za-z]+\s*\d{4}",  # e.g., "Epi Week 30: 22nd – 28th July 2024"
        r"Epi Week\s*\d+:\s*\d+\s*[–-]\s*\d+\s*[A-Za-z]+\s*\d{4}",           # e.g., "Epi Week 29: 18 – 24 July 2022"
        r"Epi Week\s*\d+[^\n]{0,100}\d{4}",                                  # More general
        r"Epi Week[^\n]{0,150}",                                             # Even more general
    ]
    
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page_num, page in enumerate(pdf.pages[:3]):  # Check first 3 pages
                text = page.extract_text()
                
                if text:
                    # Clean text: remove extra whitespace
                    cleaned_text = ' '.join(text.split())
                    
                    # Search for patterns
                    for pattern in patterns:
                        match = re.search(pattern, cleaned_text, re.IGNORECASE)
                        if match:
                            return match.group().strip()
                    
                    # Fallback: line-by-line search for "Epi Week"
                    for line in text.split('\n'):
                        if 'Epi Week' in line:
                            return ' '.join(line.split())  # clean whitespace
                            
    except Exception as e:
        print(f"Error processing PDF: {e}")
        return None
    
    return None  # return None if not found

# %% [markdown]
# ### Main

# %%
def get_data_from_pdf(pdf_path: str) -> Optional[Dict[str, Any]]:
    """
    Extract epidemiological data from a Lassa Fever PDF report.
    Retrieves Epi Week, suspected, confirmed, probable cases, and deaths.
    Handles multiple table formats.

    Args:
        pdf_path (str): Path to the PDF file.

    Returns:
        dict or None: Dictionary with keys:
            - 'epi_week'
            - 'suspected_cases'
            - 'confirmed_cases'
            - 'probable_cases'
            - 'deaths'
        Returns None if the PDF is missing or cannot be processed.
    """
    try:
        # Extract Epi Week string
        epi_week = extract_epi_week(pdf_path)

        # Extract table content and parse case numbers
        table_content = extract_table_from_pdf(pdf_path)
        tup = extract_case_data_from_table(table_content)
        
        # Return structured data as dictionary
        return {
            'epi_week': epi_week,
            'suspected_cases': tup[0],
            'confirmed_cases': tup[1],
            'probable_cases': tup[2],
            'deaths': tup[3]
        }

    except FileNotFoundError:
        print(f"Error: File not found at {pdf_path}")
        return None
    except Exception as e:
        print(f"Error processing PDF: {str(e)}")
        return None

# %%
def process_all_reports(directory_path: str) -> pd.DataFrame:
    """
    Process all PDF files in a directory and extract epidemiological data
    for time series analysis.

    Args:
        directory_path (str): Path to directory containing PDF files.

    Returns:
        pd.DataFrame: DataFrame with columns including week start/end dates,
        Epi Week info, cases (suspected, confirmed, probable, deaths),
        extraction method, and timestamp.
    """
    data_records = []

    # Get all PDF files and sort by filename
    pdf_files = [f for f in os.listdir(directory_path) if f.endswith('.pdf')]
    pdf_files.sort()  # ensures chronological order like 2020-W01.pdf, 2020-W02.pdf, etc.

    print(f"Found {len(pdf_files)} PDF files to process")

    for filename in pdf_files:
        # Extract year and week from filename
        match = re.match(r'(\d{4})-W(\d{2})\.pdf', filename)
        if not match:
            print(f"Skipping invalid filename: {filename}")
            continue

        year = int(match.group(1))
        week = int(match.group(2))

        # Calculate start (Monday) and end (Sunday) dates of the ISO week
        week_start_date, week_end_date = get_week_start_and_end_date(year, week)

        # Full path to PDF
        pdf_path = os.path.join(directory_path, filename)

        # Extract data from PDF
        result = get_data_from_pdf(pdf_path)

        if result:
            # Successful extraction
            record = {
                'week_start_date': week_start_date,
                'week_end_date': week_end_date,
                'epi_year': year,
                'epi_week': week,
                'filename': filename,
                'epi_week_info': result['epi_week'],
                'suspected_cases': result['suspected_cases'],
                'confirmed_cases': result['confirmed_cases'],
                'probable_cases': result['probable_cases'],
                'deaths': result['deaths'],
                'extraction_method': "automated",
                'extraction_timestamp': dt.datetime.now().isoformat(),
            }
            data_records.append(record)
            print(f"✓ Processed {filename}: {result['confirmed_cases']} confirmed cases")
        else:
            # For placeholder files or failed extraction
            record = {
                'week_start_date': week_start_date,
                'week_end_date': week_end_date,
                'epi_year': year,
                'epi_week': week,
                'filename': filename,
                'epi_week_info': None,
                'suspected_cases': None,
                'confirmed_cases': None,
                'probable_cases': None,
                'deaths': None,
                'extraction_method': "manual",
                'extraction_timestamp': None,
            }
            data_records.append(record)
            print(f"✗ Failed to extract data from {filename}")

    # Create DataFrame
    df = pd.DataFrame(data_records)

    # Sort by week start date to ensure chronological order
    df = df.sort_values('week_start_date').reset_index(drop=True)

    return df


# ------------------ Main execution ------------------
if __name__ == "__main__":
    directory_path = "/kaggle/working/ncdc_reports"

    # Process all reports in the directory
    final_df = process_all_reports(directory_path)

    # Display summary
    print("\n" + "="*50)
    print("EXTRACTED DATA SUMMARY")
    print("="*50)
    print(f"Total records: {len(final_df)}")
    print(f"Records with case data: {final_df['confirmed_cases'].notna().sum()}")
    print(f"Date range: {final_df['week_start_date'].min()} to {final_df['week_start_date'].max()}")
# Out:
# Found 302 PDF files to process
# ✓ Processed 2020-W01.pdf:  confirmed cases
# ✓ Processed 2020-W02.pdf:  confirmed cases
# ✓ Processed 2020-W03.pdf:  confirmed cases
# ✓ Processed 2020-W04.pdf: 95 confirmed cases
# ✓ Processed 2020-W05.pdf: 104 confirmed cases
# ✓ Processed 2020-W06.pdf: 109 confirmed cases
# ✓ Processed 2020-W07.pdf: 115 confirmed cases
# ✓ Processed 2020-W08.pdf: 102 confirmed cases
# ✓ Processed 2020-W09.pdf: 85 confirmed cases
# ✓ Processed 2020-W10.pdf: 81 confirmed cases
# ✓ Processed 2020-W11.pdf: 51 confirmed cases
# ✓ Processed 2020-W12.pdf: 28 confirmed cases
# ✓ Processed 2020-W13.pdf: 19 confirmed cases
# ✓ Processed 2020-W14.pdf: 12 confirmed cases
# ✓ Processed 2020-W15.pdf: 10 confirmed cases
# ✓ Processed 2020-W16.pdf: 6 confirmed cases
# ✓ Processed 2020-W17.pdf: 8 confirmed cases
# ✓ Processed 2020-W18.pdf: 5 confirmed cases
# ✓ Processed 2020-W19.pdf: 9 confirmed cases
# ✓ Processed 2020-W20.pdf: 6 confirmed cases
# ✓ Processed 2020-W21.pdf: 9 confirmed cases
# ✓ Processed 2020-W22.pdf: 6 confirmed cases
# ✓ Processed 2020-W23.pdf: 5 confirmed cases
# ✓ Processed 2020-W24.pdf: 5 confirmed cases
# ✓ Processed 2020-W25.pdf: 5 confirmed cases
# ✓ Processed 2020-W26.pdf: 4 confirmed cases
# ✓ Processed 2020-W27.pdf: 3 confirmed cases
# ✓ Processed 2020-W28.pdf: 3 confirmed cases
# ✓ Processed 2020-W29.pdf: 5 confirmed cases
# ✓ Processed 2020-W30.pdf: 0 confirmed cases
# ✓ Processed 2020-W31.pdf: 3 confirmed cases
# ✓ Processed 2020-W32.pdf: 6 confirmed cases
# ✓ Processed 2020-W33.pdf: 1 confirmed cases
# ✓ Processed 2020-W34.pdf: 11 confirmed cases
# ✓ Processed 2020-W35.pdf: 2 confirmed cases
# ✓ Processed 2020-W36.pdf: 4 confirmed cases
# ✓ Processed 2020-W37.pdf: 6 confirmed cases
# ✓ Processed 2020-W38.pdf: 4 confirmed cases
# ✓ Processed 2020-W39.pdf: 7 confirmed cases
# ✓ Processed 2020-W40.pdf: 3 confirmed cases
# ✓ Processed 2020-W41.pdf: 5 confirmed cases
# ✓ Processed 2020-W42.pdf: 13 confirmed cases
# ✓ Processed 2020-W43.pdf: 3 confirmed cases
# ✓ Processed 2020-W44.pdf: 11 confirmed cases
# ✓ Processed 2020-W45.pdf: 5 confirmed cases
# ✓ Processed 2020-W46.pdf: 2 confirmed cases
# ✓ Processed 2020-W47.pdf: 10 confirmed cases
# ✓ Processed 2020-W48.pdf: 6 confirmed cases
# ✓ Processed 2020-W49.pdf: 4 confirmed cases
# ✓ Processed 2020-W50.pdf: 5 confirmed cases
# ✓ Processed 2020-W51.pdf: 12 confirmed cases
# ✓ Processed 2020-W52.pdf: 6 confirmed cases
# ✓ Processed 2020-W53.pdf: 8 confirmed cases
# ✓ Processed 2021-W01.pdf: 9 confirmed cases
# ✓ Processed 2021-W02.pdf: 14 confirmed cases
# ✓ Processed 2021-W03.pdf: 17 confirmed cases
# ✓ Processed 2021-W04.pdf: 14 confirmed cases
# ✓ Processed 2021-W05.pdf: 12 confirmed cases
# ✓ Processed 2021-W06.pdf: 17 confirmed cases
# ✓ Processed 2021-W07.pdf: 19 confirmed cases
# ✓ Processed 2021-W08.pdf: 34 confirmed cases
# ✓ Processed 2021-W09.pdf: 25 confirmed cases
# ✓ Processed 2021-W10.pdf: 30 confirmed cases
# ✓ Processed 2021-W11.pdf: 32 confirmed cases
# ✓ Processed 2021-W12.pdf: 7 confirmed cases
# ✓ Processed 2021-W13.pdf: 3 confirmed cases
# ✓ Processed 2021-W14.pdf: 8 confirmed cases
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2021-W15.pdf
# ✓ Processed 2021-W16.pdf: 7 confirmed cases
# ✓ Processed 2021-W17.pdf: 8 confirmed cases
# ✓ Processed 2021-W18.pdf: 10 confirmed cases
# ✓ Processed 2021-W19.pdf: 1 confirmed cases
# ✓ Processed 2021-W20.pdf: 8 confirmed cases
# Error processing PDF: Unexpected EOF
# Error processing PDF: Unexpected EOF
# ✗ Failed to extract data from 2021-W21.pdf
# ✓ Processed 2021-W22.pdf: 6 confirmed cases
# Error processing PDF: Unexpected EOF
# Error processing PDF: Unexpected EOF
# ✗ Failed to extract data from 2021-W23.pdf
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2021-W25.pdf
# ✓ Processed 2021-W26.pdf: 3 confirmed cases
# ✓ Processed 2021-W27.pdf: 7 confirmed cases
# ✓ Processed 2021-W28.pdf: 5 confirmed cases
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2021-W29.pdf
# Error processing PDF: Unexpected EOF
# Error processing PDF: Unexpected EOF
# ✗ Failed to extract data from 2021-W30.pdf
# ✓ Processed 2021-W31.pdf: 4 confirmed cases
# Error processing PDF: Unexpected EOF
# Error processing PDF: Unexpected EOF
# ✗ Failed to extract data from 2021-W32.pdf
# ✓ Processed 2021-W33.pdf: 2 confirmed cases
# ✓ Processed 2021-W34.pdf: 9 confirmed cases
# ✓ Processed 2021-W35.pdf: 0 confirmed cases
# ✓ Processed 2021-W36.pdf: 4 confirmed cases
# ✓ Processed 2021-W37.pdf: 1 confirmed cases
# ✓ Processed 2021-W38.pdf: 9 confirmed cases
# ✓ Processed 2021-W39.pdf: 3 confirmed cases
# ✓ Processed 2021-W40.pdf: 4 confirmed cases
# ✓ Processed 2021-W41.pdf: 7 confirmed cases
# ✓ Processed 2021-W42.pdf: 8 confirmed cases
# ✓ Processed 2021-W43.pdf: 2 confirmed cases
# ✓ Processed 2021-W44.pdf: 7 confirmed cases
# ✓ Processed 2021-W45.pdf: 8 confirmed cases
# ✓ Processed 2021-W46.pdf: 9 confirmed cases
# ✓ Processed 2021-W47.pdf: 3 confirmed cases
# ✓ Processed 2021-W48.pdf: 4 confirmed cases
# ✓ Processed 2021-W49.pdf: 10 confirmed cases
# ✓ Processed 2021-W50.pdf: 10 confirmed cases
# ✓ Processed 2021-W51.pdf: 29 confirmed cases
# ✓ Processed 2021-W52.pdf: 28 confirmed cases
# ✓ Processed 2021-W53.pdf: 48 confirmed cases
# ✓ Processed 2022-W01.pdf: 48 confirmed cases
# ✓ Processed 2022-W02.pdf: 74 confirmed cases
# ✓ Processed 2022-W03.pdf: 42 confirmed cases
# ✓ Processed 2022-W04.pdf: 58 confirmed cases
# ✓ Processed 2022-W05.pdf: 77 confirmed cases
# ✓ Processed 2022-W06.pdf: 91 confirmed cases
# ✓ Processed 2022-W07.pdf: 90 confirmed cases
# ✓ Processed 2022-W08.pdf: 57 confirmed cases
# ✓ Processed 2022-W09.pdf: 33 confirmed cases
# ✓ Processed 2022-W10.pdf: 29 confirmed cases
# ✓ Processed 2022-W11.pdf: 22 confirmed cases
# ✓ Processed 2022-W12.pdf: 10 confirmed cases
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W13.pdf
# ✓ Processed 2022-W14.pdf: 18 confirmed cases
# ✓ Processed 2022-W15.pdf: 18 confirmed cases
# ✓ Processed 2022-W16.pdf: 8 confirmed cases
# ✓ Processed 2022-W17.pdf: 3 confirmed cases
# Error processing PDF: Unexpected EOF
# Error processing PDF: Unexpected EOF
# ✗ Failed to extract data from 2022-W18.pdf
# Error processing PDF: Unexpected EOF
# Error processing PDF: Unexpected EOF
# ✗ Failed to extract data from 2022-W19.pdf
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W21.pdf
# ✓ Processed 2022-W22.pdf: 8 confirmed cases
# ✓ Processed 2022-W23.pdf: 10 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2022-W24.pdf: 9 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2022-W25.pdf: med Probab
# es cases
# 0 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2022-W26.pdf: med Probabl
# es cases
# 0 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2022-W27.pdf: med Probab
# s cases
# 0 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2022-W28.pdf: Deaths
# e
# (Confirmed
# cases)
# 0 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2022-W29.pdf: Deaths
# e C
# (Confirmed
# cases)
# 1 confirmed cases
# ✓ Processed 2022-W30.pdf: 9 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2022-W31.pdf: 5 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W32.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W33.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W34.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2022-W35.pdf: 6 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W36.pdf
# ✓ Processed 2022-W37.pdf: 4 confirmed cases
# ✓ Processed 2022-W38.pdf: 4 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2022-W39.pdf: 4 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W40.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W41.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2022-W42.pdf: 17 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W43.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W44.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W45.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W46.pdf
# ✓ Processed 2022-W47.pdf: 13 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2022-W48.pdf: 10 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W49.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W50.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W51.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W52.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2022-W53.pdf
# ✓ Processed 2023-W01.pdf: 117 confirmed cases
# ✓ Processed 2023-W02.pdf: 106 confirmed cases
# ✓ Processed 2023-W03.pdf: 68 confirmed cases
# ✓ Processed 2023-W04.pdf: 46 confirmed cases
# ✓ Processed 2023-W05.pdf: 59 confirmed cases
# ✓ Processed 2023-W06.pdf: 40 confirmed cases
# ✓ Processed 2023-W07.pdf: 70 confirmed cases
# ✓ Processed 2023-W08.pdf: 38 confirmed cases
# ✓ Processed 2023-W09.pdf: 39 confirmed cases
# ✓ Processed 2023-W10.pdf: 23 confirmed cases
# ✓ Processed 2023-W11.pdf: 23 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2023-W12.pdf: 9 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2023-W13.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2023-W14.pdf
# ✓ Processed 2023-W15.pdf: 10 confirmed cases
# ✓ Processed 2023-W16.pdf: 7 confirmed cases
# ✓ Processed 2023-W17.pdf: 8 confirmed cases
# ✓ Processed 2023-W18.pdf: 7 confirmed cases
# ✓ Processed 2023-W19.pdf: 7 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2023-W20.pdf: 1 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2023-W21.pdf
# ✓ Processed 2023-W22.pdf: 10 confirmed cases
# ✓ Processed 2023-W23.pdf: 10 confirmed cases
# ✓ Processed 2023-W24.pdf: 6 confirmed cases
# ✓ Processed 2023-W25.pdf: 10 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2023-W26.pdf: 9 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2023-W27.pdf: Probable
# (
# cases
# 0 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2023-W28.pdf: Probable
# (C
# cases
# 0 confirmed cases
# ✓ Processed 2023-W29.pdf: 5 confirmed cases
# ✓ Processed 2023-W30.pdf: 9 confirmed cases
# ✓ Processed 2023-W31.pdf: 11 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2023-W32.pdf: 6 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2023-W33.pdf: Probable
# cases
# 0 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2023-W34.pdf: ed Probable
# (
# s cases
# 0 confirmed cases
# ✓ Processed 2023-W36.pdf: 9 confirmed cases
# ✓ Processed 2023-W37.pdf: 5 confirmed cases
# ✓ Processed 2023-W38.pdf: 9 confirmed cases
# ✓ Processed 2023-W39.pdf: 9 confirmed cases
# ✓ Processed 2023-W40.pdf: 3 confirmed cases
# ✓ Processed 2023-W41.pdf: 8 confirmed cases
# ✓ Processed 2023-W42.pdf: 12 confirmed cases
# ✓ Processed 2023-W43.pdf: 17 confirmed cases
# ✓ Processed 2023-W44.pdf: 11 confirmed cases
# ✓ Processed 2023-W45.pdf: 16 confirmed cases
# ✓ Processed 2023-W46.pdf: 21 confirmed cases
# ✓ Processed 2023-W47.pdf: 10 confirmed cases
# ✓ Processed 2023-W48.pdf: 26 confirmed cases
# ✓ Processed 2023-W49.pdf: 43 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2023-W50.pdf: 53 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2023-W51.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2023-W52.pdf
# ✓ Processed 2023-W53.pdf: 47 confirmed cases
# ✓ Processed 2024-W01.pdf: 70 confirmed cases
# ✓ Processed 2024-W02.pdf: 83 confirmed cases
# ✓ Processed 2024-W03.pdf: 66 confirmed cases
# ✓ Processed 2024-W04.pdf: 96 confirmed cases
# ✓ Processed 2024-W05.pdf: 109 confirmed cases
# ✓ Processed 2024-W06.pdf: 50 confirmed cases
# ✓ Processed 2024-W07.pdf: 35 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2024-W08.pdf: 25 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2024-W09.pdf
# ✓ Processed 2024-W10.pdf: 11 confirmed cases
# ✓ Processed 2024-W11.pdf: 15 confirmed cases
# ✓ Processed 2024-W12.pdf: 14 confirmed cases
# ✓ Processed 2024-W13.pdf: 14 confirmed cases
# ✓ Processed 2024-W14.pdf: 12 confirmed cases
# ✓ Processed 2024-W15.pdf: 14 confirmed cases
# ✓ Processed 2024-W16.pdf: 4 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2024-W17.pdf: 10 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2024-W18.pdf
# ✓ Processed 2024-W19.pdf: 4 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✓ Processed 2024-W20.pdf: 7 confirmed cases
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2024-W21.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2024-W22.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2024-W23.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2024-W24.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2024-W25.pdf
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Error processing PDF: 'NoneType' object is not subscriptable
# ✗ Failed to extract data from 2024-W26.pdf
# ✓ Processed 2024-W27.pdf: 3 confirmed cases
# ✓ Processed 2024-W28.pdf: 10 confirmed cases
# ✓ Processed 2024-W29.pdf: 8 confirmed cases
# ✓ Processed 2024-W30.pdf: 3 confirmed cases
# ✓ Processed 2024-W31.pdf: 11 confirmed cases
# ✓ Processed 2024-W32.pdf: 7 confirmed cases
# ✓ Processed 2024-W33.pdf: 5 confirmed cases
# ✓ Processed 2024-W34.pdf: 4 confirmed cases
# ✓ Processed 2024-W35.pdf: 9 confirmed cases
# ✓ Processed 2024-W36.pdf: 7 confirmed cases
# ✓ Processed 2024-W37.pdf: 10 confirmed cases
# ✓ Processed 2024-W38.pdf: 12 confirmed cases
# ✓ Processed 2024-W39.pdf: 8 confirmed cases
# ✓ Processed 2024-W40.pdf: 4 confirmed cases
# ✓ Processed 2024-W41.pdf: 10 confirmed cases
# ✓ Processed 2024-W42.pdf: 8 confirmed cases
# ✓ Processed 2024-W43.pdf: 12 confirmed cases
# ✓ Processed 2024-W44.pdf: 26 confirmed cases
# ✓ Processed 2024-W45.pdf: 39 confirmed cases
# ✓ Processed 2024-W46.pdf: 33 confirmed cases
# ✓ Processed 2024-W47.pdf: 50 confirmed cases
# ✓ Processed 2024-W48.pdf: 70 confirmed cases
# ✓ Processed 2024-W49.pdf: 54 confirmed cases
# ✓ Processed 2024-W50.pdf: 89 confirmed cases
# ✓ Processed 2024-W51.pdf: 71 confirmed cases
# ✓ Processed 2024-W52.pdf: 76 confirmed cases
# ✓ Processed 2024-W53.pdf: 68 confirmed cases
# ✓ Processed 2025-W01.pdf: 54 confirmed cases
# ✓ Processed 2025-W02.pdf: 38 confirmed cases
# ✓ Processed 2025-W03.pdf: 54 confirmed cases
# ✓ Processed 2025-W04.pdf: 29 confirmed cases
# ✓ Processed 2025-W05.pdf: 28 confirmed cases
# ✓ Processed 2025-W06.pdf: 40 confirmed cases
# ✓ Processed 2025-W07.pdf: 41 confirmed cases
# ✓ Processed 2025-W08.pdf: 14 confirmed cases
# ✓ Processed 2025-W09.pdf: 15 confirmed cases
# ✓ Processed 2025-W10.pdf: 12 confirmed cases
# ✓ Processed 2025-W11.pdf: 10 confirmed cases
# ✓ Processed 2025-W12.pdf: 11 confirmed cases
# ✓ Processed 2025-W13.pdf: 10 confirmed cases
# ✓ Processed 2025-W14.pdf: 3 confirmed cases
# ✓ Processed 2025-W15.pdf: 13 confirmed cases
# ✓ Processed 2025-W16.pdf: 6 confirmed cases
# ✓ Processed 2025-W17.pdf: 8 confirmed cases
# ✓ Processed 2025-W18.pdf: 11 confirmed cases
# ✓ Processed 2025-W19.pdf: 8 confirmed cases
# ✓ Processed 2025-W20.pdf: 10 confirmed cases
# ✓ Processed 2025-W21.pdf: 9 confirmed cases
# ✓ Processed 2025-W22.pdf: 11 confirmed cases
# ✓ Processed 2025-W23.pdf: 11 confirmed cases
# ✓ Processed 2025-W24.pdf: 11 confirmed cases
# ✓ Processed 2025-W25.pdf: 3 confirmed cases
# ✓ Processed 2025-W26.pdf: 9 confirmed cases
# ✓ Processed 2025-W27.pdf: 12 confirmed cases
# ✓ Processed 2025-W28.pdf: 5 confirmed cases
# ✓ Processed 2025-W29.pdf: 3 confirmed cases
# ✓ Processed 2025-W30.pdf: 10 confirmed cases
# ✓ Processed 2025-W31.pdf: 13 confirmed cases
# ✓ Processed 2025-W32.pdf: 11 confirmed cases
# ✓ Processed 2025-W33.pdf: 11 confirmed cases
# ✓ Processed 2025-W34.pdf: 4 confirmed cases
# ✓ Processed 2025-W35.pdf: 13 confirmed cases
# ✓ Processed 2025-W36.pdf: 11 confirmed cases
# ✓ Processed 2025-W37.pdf: 9 confirmed cases
# ✓ Processed 2025-W38.pdf: 11 confirmed cases
# ✓ Processed 2025-W39.pdf: 12 confirmed cases
# ✓ Processed 2025-W40.pdf: 10 confirmed cases
#
# ==================================================
# EXTRACTED DATA SUMMARY
# ==================================================
# Total records: 302
# Records with case data: 263
# Date range: 2019-12-30 00:00:00 to 2025-09-29 00:00:00

# %% [markdown]
# ### Export / Save Processed Data

# %%
# Add PDF URLs to final DataFrame 
urls = []

# Start from START_SN - 1 to match the first PDF in pdf_data
index = START_SN - 1

for sn in range(len(final_df)):
    appropriate_url = pdf_data[index][2]
    urls.append(appropriate_url)

    index -= 1 
    
final_df["report_pdf_url"] = urls

# %%
# Save to CSV
csv_path = "/kaggle/working/lassa_fever_timeseries.csv"
final_df.to_csv(csv_path, index=False)
print(f"\nData saved to: {csv_path}")
# Out:
# Data saved to: /kaggle/working/lassa_fever_timeseries.csv

# %% [markdown]
# ## Cleanup / Additional Formatting

# %%
# create zip file 

directory_path = "/kaggle/working/ncdc_reports"
zip_filename = "/kaggle/working/ncdc_reports.zip"

# Create zip file
shutil.make_archive(
    base_name="/kaggle/working/ncdc_reports", 
    format='zip',
    root_dir=directory_path
)

print(f"Zip file created: {zip_filename}")
# Out:
# Zip file created: /kaggle/working/ncdc_reports.zip

# %%
# delete all files 
import os
import glob

directory_path = "/kaggle/working/ncdc_reports"

files = glob.glob(os.path.join(directory_path, "*"))
for file in files:
    if os.path.isfile(file):
        os.remove(file)
        print(f"Deleted: {file}")

print("All files deleted!")
# Out:
# Deleted: /kaggle/working/ncdc_reports/2023-W27.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W29.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W10.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W44.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W34.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W28.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W43.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W31.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W43.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W15.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W28.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W36.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W42.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W37.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W19.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W18.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W31.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W52.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W05.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W29.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W20.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W20.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W26.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W02.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W33.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W51.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W24.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W07.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W35.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W28.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W38.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W06.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W12.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W32.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W49.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W44.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W08.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W17.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W02.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W03.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W04.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W13.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W20.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W44.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W05.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W51.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W23.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W51.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W29.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W52.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W32.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W25.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W46.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W50.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W43.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W44.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W30.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W10.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W52.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W47.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W40.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W18.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W37.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W24.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W34.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W31.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W22.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W25.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W09.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W48.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W06.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W19.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W22.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W08.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W30.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W16.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W38.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W39.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W41.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W35.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W21.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W40.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W47.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W09.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W18.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W48.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W50.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W47.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W33.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W01.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W17.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W15.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W21.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W18.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W12.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W30.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W08.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W25.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W49.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W45.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W01.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W40.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W17.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W31.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W45.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W05.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W52.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W21.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W34.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W04.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W42.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W06.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W02.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W14.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W22.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W29.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W38.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W29.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W36.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W05.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W14.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W32.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W36.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W01.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W18.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W32.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W13.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W26.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W02.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W36.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W10.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W31.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W53.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W18.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W03.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W27.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W03.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W05.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W17.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W13.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W42.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W37.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W06.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W02.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W13.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W07.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W16.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W27.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W21.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W33.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W26.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W16.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W12.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W08.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W27.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W19.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W37.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W32.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W35.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W50.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W07.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W12.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W49.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W22.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W40.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W19.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W45.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W11.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W36.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W29.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W42.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W10.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W11.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W09.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W21.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W39.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W17.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W23.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W10.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W26.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W37.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W48.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W48.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W19.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W15.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W33.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W49.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W43.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W44.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W06.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W01.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W45.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W14.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W46.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W07.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W28.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W16.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W03.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W11.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W11.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W53.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W08.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W03.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W41.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W11.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W40.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W01.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W30.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W04.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W28.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W14.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W39.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W50.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W22.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W53.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W11.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W16.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W12.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W40.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W23.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W28.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W33.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W46.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W51.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W52.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W35.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W51.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W31.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W30.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W41.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W25.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W27.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W13.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W20.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W26.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W46.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W33.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W48.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W38.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W16.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W14.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W39.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W53.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W37.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W25.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W34.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W42.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W04.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W20.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W36.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W01.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W09.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W41.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W46.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W38.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W07.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W22.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W19.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W25.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W06.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W41.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W12.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W30.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W34.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W49.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W24.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W04.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W10.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W23.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W02.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W15.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W07.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W21.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W38.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W35.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W05.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W34.pdf
# Deleted: /kaggle/working/ncdc_reports/2024-W50.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W43.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W09.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W26.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W09.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W45.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W24.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W03.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W14.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W39.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W47.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W15.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W23.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W23.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W15.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W08.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W39.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W27.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W17.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W24.pdf
# Deleted: /kaggle/working/ncdc_reports/2023-W53.pdf
# Deleted: /kaggle/working/ncdc_reports/2021-W47.pdf
# Deleted: /kaggle/working/ncdc_reports/2025-W32.pdf
# Deleted: /kaggle/working/ncdc_reports/2022-W04.pdf
# Deleted: /kaggle/working/ncdc_reports/2020-W13.pdf
# All files deleted!
